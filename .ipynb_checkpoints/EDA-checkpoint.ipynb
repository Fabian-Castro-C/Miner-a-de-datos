# %%
import pandas as pd


dielectric = pd.read_csv("dielectric_doc")
electronic = pd.read_csv("electronic_doc")
magnetic = pd.read_csv("magnetic_doc.csv")
material = pd.read_csv("mat_doc")
oxidation_states=pd.read_csv("oxidation_states_doc")
thermo = pd.read_csv("thermo_doc")

dataframes = [dielectric,electronic,magnetic,material,oxidation_states,thermo]

# %%
for i, df in enumerate(dataframes):
    if 'Unnamed: 0' in df.columns:
        dataframes[i] = df.drop(columns='Unnamed: 0')

# %%
dielectric = dataframes[0]
electronic = dataframes[1]
magnetic = dataframes[2]
material = dataframes[3]
oxidation_states = dataframes[4]
thermo = dataframes[5]

# %%
import matplotlib.pyplot as plt

# Supongamos que tienes una lista de DataFrames llamada 'dataframes_list'
# Cada DataFrame en la lista representa un conjunto de datos
i = 0
for df in dataframes:
    print("analisis estadístico dataframe " + str(i) )
    for column in df.columns[1:]:
        print("Histograma de columna" + str({column}))
        
        plt.figure(figsize=(8, 4))
        
        # Verificar si la columna contiene valores booleanos
        if df[column].dtype == bool:
            data_clean = df[column].value_counts()
            data_clean.plot(kind='bar', rot=0)
        else:
            data_clean = df[column]#.dropna()  # Eliminar filas con NaN en la columna
            
            plt.hist(data_clean, bins=20)
        
        plt.title(f'Histograma de {column}')
        plt.xlabel(column)
        plt.ylabel('Frecuencia')
        plt.show()
    i+=1
# Out:
# analisis estadístico dataframe 0
# Histograma de columna{'e_total'}
# Histograma de columna{'e_ionic'}
# Histograma de columna{'e_electronic'}
# Histograma de columna{'n'}
# analisis estadístico dataframe 1
# Histograma de columna{'band_gap'}
# Histograma de columna{'efermi'}
# Histograma de columna{'is_metal'}
# analisis estadístico dataframe 2
# Histograma de columna{'is_magnetic'}
# Histograma de columna{'exchange_symmetry'}
# Histograma de columna{'num_magnetic_sites'}
# analisis estadístico dataframe 3
# Histograma de columna{'composition'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 25
#      23     plt.xlabel(column)
#      24     plt.ylabel('Frecuencia')
# ---> 25     plt.show()
#      26 i+=1
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\IPython\core\formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\IPython\core\formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\backend_bases.py:2342, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2336     renderer = _get_renderer(
#    2337         self.figure,
#    2338         functools.partial(
#    2339             print_method, orientation=orientation)
#    2340     )
#    2341     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2342         self.figure.draw(renderer)
#    2344 if bbox_inches:
#    2345     if bbox_inches == "tight":
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\figure.py:3175, in Figure.draw(self, renderer)
#    3172         # ValueError can occur when resizing a window.
#    3174 self.patch.draw(renderer)
# -> 3175 mimage._draw_list_compositing_images(
#    3176     renderer, self, artists, self.suppressComposite)
#    3178 for sfig in self.subfigs:
#    3179     sfig.draw(renderer)
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\axes\_base.py:3064, in _AxesBase.draw(self, renderer)
#    3061 if artists_rasterized:
#    3062     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3064 mimage._draw_list_compositing_images(
#    3065     renderer, self, artists, self.figure.suppressComposite)
#    3067 renderer.close_group('axes')
#    3068 self.stale = False
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\axis.py:1376, in Axis.draw(self, renderer, *args, **kwargs)
#    1373     return
#    1374 renderer.open_group(__name__, gid=self.get_gid())
# -> 1376 ticks_to_draw = self._update_ticks()
#    1377 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1379 for tick in ticks_to_draw:
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\axis.py:1264, in Axis._update_ticks(self)
#    1262 major_locs = self.get_majorticklocs()
#    1263 major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1264 major_ticks = self.get_major_ticks(len(major_locs))
#    1265 self.major.formatter.set_locs(major_locs)
#    1266 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\axis.py:1604, in Axis.get_major_ticks(self, numticks)
#    1602     tick = self._get_tick(major=True)
#    1603     self.majorTicks.append(tick)
# -> 1604     self._copy_tick_props(self.majorTicks[0], tick)
#    1606 return self.majorTicks[:numticks]
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\axis.py:1571, in Axis._copy_tick_props(self, src, dest)
#    1569 dest.label1.update_from(src.label1)
#    1570 dest.label2.update_from(src.label2)
# -> 1571 dest.tick1line.update_from(src.tick1line)
#    1572 dest.tick2line.update_from(src.tick2line)
#    1573 dest.gridline.update_from(src.gridline)
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\lines.py:1354, in Line2D.update_from(self, other)
#    1351 self._solidjoinstyle = other._solidjoinstyle
#    1353 self._linestyle = other._linestyle
# -> 1354 self._marker = MarkerStyle(marker=other._marker)
#    1355 self._drawstyle = other._drawstyle
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\markers.py:272, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     267     marker = ""
#     268     _api.warn_deprecated(
#     269         "3.6", message="MarkerStyle(None) is deprecated since "
#     270         "%(since)s; support will be removed %(removal)s.  Use "
#     271         "MarkerStyle('') to construct an empty MarkerStyle.")
# --> 272 self._set_marker(marker)
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\markers.py:355, in MarkerStyle._set_marker(self, marker)
#     352     self._marker_function = getattr(
#     353         self, '_set_' + self.markers[marker])
#     354 elif isinstance(marker, MarkerStyle):
# --> 355     self.__dict__ = copy.deepcopy(marker.__dict__)
#     357 else:
#     358     try:
#
# File C:\Python310\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File C:\Python310\lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File C:\Python310\lib\copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# File c:\Users\Seba\Documents\GitHub\Miner-a-de-datos\.venv\lib\site-packages\matplotlib\path.py:287, in Path.__deepcopy__(self, memo)
#     282 """
#     283 Return a deepcopy of the `Path`.  The `Path` will not be
#     284 readonly, even if the source `Path` is.
#     285 """
#     286 # Deepcopying arrays (vertices, codes) strips the writeable=False flag.
# --> 287 p = copy.deepcopy(super(), memo)
#     288 p._readonly = False
#     289 return p
#
# File C:\Python310\lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File C:\Python310\lib\copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File C:\Python310\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File C:\Python310\lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File C:\Python310\lib\copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# KeyboardInterrupt:
