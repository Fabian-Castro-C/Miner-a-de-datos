# %% [markdown]
# # Materials Project

# %%
from mp_api.client import MPRester
import numpy as np
import matplotlib.pyplot as plt


api_key = 'UARe7yEMS23Sn3kFfif6tjCAAw2uinQ4'

# %%
from pymatgen.electronic_structure.plotter import DosPlotter

with MPRester(api_key) as mpr:
    material_id = 'mp-8'  # Cambia esto al material_id que desees
    doc = mpr.summary.search(material_ids=[material_id])
    dos = mpr.get_dos_by_material_id(material_id)

# Crea un objeto DosPlotter y genera el gráfico de la DOS
dos_plotter = DosPlotter()
dos_plotter.add_dos("DOS del material", dos)
dos_plotter.get_plot(xlim=(-5, 5))  # Personaliza los límites del eje x según tu necesidad
plt.title(f"Densidad de estados para {material_id}")
plt.xlabel("Energía (eV)")
plt.ylabel("Densidad de estados")
plt.show()
# Out:
# d:\Universidad\Semestre 10\Minería de datos\Proyecto\Ambiente virtual\MPApi\lib\site-packages\mp_api\client\mprester.py:192: UserWarning: mpcontribs-client not installed. Install the package to query MPContribs data, or construct pourbaix diagrams: 'pip install mpcontribs-client'
#   warnings.warn(
# C:\Users\fabca\AppData\Local\Temp\ipykernel_12388\2635365958.py:5: DeprecationWarning: Accessing summary data through MPRester.summary is deprecated. Please use MPRester.materials.summary instead.
#   doc = mpr.summary.search(material_ids=[material_id])
# ...
# Retrieving ElectronicStructureDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]

# %%
doc[0].formula_pretty
# Out:
# 'Re'
